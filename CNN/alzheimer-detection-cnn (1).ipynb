# %% [markdown]
# # LIBRARIES

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.image as img
# %matplotlib inline

# %% [markdown]
# # DATA LOAD

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio(r'C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\dataset\archive\Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))
# Out:
# Requirement already satisfied: split-folders in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (0.5.1)
# Copying files: 6400 files [00:12, 517.65 files/s]

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123, label_mode='categorical',
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,label_mode='categorical',
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,label_mode='categorical',
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 5119 files belonging to 4 classes.
# Found 642 files belonging to 4 classes.
# Found 639 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>

# %% [markdown]
# # EXAMPLE IMAGE

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[int(max(labels[i]))])
        plt.axis("off")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [896,64,3200,2240]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # MODEL

# %%
model = keras.models.Sequential()
model.add(keras.layers.Rescaling(1./255, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)))
model.add(keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))


model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))

model.add(keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
model.add(keras.layers.Dense(32,"relu"))
model.add(keras.layers.Dense(4,"softmax"))
# Out:
# c:\Users\Nikkhil_Bisht\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss="categorical_crossentropy",
              optimizer = "Adam",metrics=['accuracy',
                                tf.keras.metrics.AUC(),
                                tf.keras.metrics.Precision(),
                                tf.keras.metrics.Recall(),])

# %%
filepath = r'C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras'
earlystopping=tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              mode='max',
                                              patience=10,
                                              verbose=1)
checkpoint= tf.keras.callbacks.ModelCheckpoint(filepath,
                           monitor='val_accuracy',
                           mode='max',
                           save_best_only=True,
                           verbose=1)

callbacks_list=[earlystopping,checkpoint]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,125,124 (8.11 MB)
#  Trainable params: 2,125,124 (8.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(model,show_shapes=True,dpi=150)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
pip install --upgrade tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (2.17.0)
# Requirement already satisfied: keras in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (3.4.1)
# Collecting keras
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\nikkhil_bisht\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\nikkhil_bisht\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.65.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: rich in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from keras) (0.12.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nikkhil_bisht\appdata\roaming\python\python312\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nikkhil_bisht\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.5)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# Successfully installed keras-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
hist = model.fit(train_ds,validation_data=val_ds,epochs=50, batch_size=64, verbose=1,
                 callbacks= callbacks_list)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.4533 - auc: 0.6998 - loss: 2.6358 - precision: 0.4662 - recall: 0.3337
# Epoch 1: val_accuracy improved from -inf to 0.50078, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 28s 319ms/step - accuracy: 0.4537 - auc: 0.7005 - loss: 2.6225 - precision: 0.4668 - recall: 0.3336 - val_accuracy: 0.5008 - val_auc: 0.8294 - val_loss: 1.0440 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5174 - auc: 0.8141 - loss: 0.9872 - precision: 0.6142 - recall: 0.3656
# Epoch 2: val_accuracy improved from 0.50078 to 0.61346, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 229ms/step - accuracy: 0.5175 - auc: 0.8141 - loss: 0.9870 - precision: 0.6145 - recall: 0.3655 - val_accuracy: 0.6135 - val_auc: 0.8622 - val_loss: 0.9780 - val_precision: 0.8733 - val_recall: 0.2050
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.5687 - auc: 0.8420 - loss: 0.9135 - precision: 0.6571 - recall: 0.4048
# Epoch 3: val_accuracy did not improve from 0.61346
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - accuracy: 0.5688 - auc: 0.8421 - loss: 0.9134 - precision: 0.6572 - recall: 0.4049 - val_accuracy: 0.5962 - val_auc: 0.8615 - val_loss: 0.8857 - val_precision: 0.7295 - val_recall: 0.3756
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5933 - auc: 0.8535 - loss: 0.8857 - precision: 0.6803 - recall: 0.4235
# Epoch 4: val_accuracy improved from 0.61346 to 0.66980, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - accuracy: 0.5935 - auc: 0.8535 - loss: 0.8855 - precision: 0.6804 - recall: 0.4236 - val_accuracy: 0.6698 - val_auc: 0.8941 - val_loss: 0.7997 - val_precision: 0.7781 - val_recall: 0.4116
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6274 - auc: 0.8737 - loss: 0.8246 - precision: 0.7059 - recall: 0.4996
# Epoch 5: val_accuracy did not improve from 0.66980
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 221ms/step - accuracy: 0.6273 - auc: 0.8738 - loss: 0.8245 - precision: 0.7059 - recall: 0.4996 - val_accuracy: 0.6088 - val_auc: 0.8812 - val_loss: 0.8164 - val_precision: 0.7473 - val_recall: 0.4304
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.6469 - auc: 0.8831 - loss: 0.7976 - precision: 0.7019 - recall: 0.5306
# Epoch 6: val_accuracy improved from 0.66980 to 0.69953, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - accuracy: 0.6469 - auc: 0.8831 - loss: 0.7975 - precision: 0.7020 - recall: 0.5307 - val_accuracy: 0.6995 - val_auc: 0.9162 - val_loss: 0.7571 - val_precision: 0.8017 - val_recall: 0.4429
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.6792 - auc: 0.9010 - loss: 0.7473 - precision: 0.7457 - recall: 0.5827
# Epoch 7: val_accuracy improved from 0.69953 to 0.72613, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 232ms/step - accuracy: 0.6792 - auc: 0.9010 - loss: 0.7472 - precision: 0.7456 - recall: 0.5828 - val_accuracy: 0.7261 - val_auc: 0.9334 - val_loss: 0.6660 - val_precision: 0.8158 - val_recall: 0.5822
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7177 - auc: 0.9224 - loss: 0.6608 - precision: 0.7688 - recall: 0.6446
# Epoch 8: val_accuracy did not improve from 0.72613
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - accuracy: 0.7177 - auc: 0.9224 - loss: 0.6607 - precision: 0.7687 - recall: 0.6446 - val_accuracy: 0.7230 - val_auc: 0.9323 - val_loss: 0.6311 - val_precision: 0.7896 - val_recall: 0.6166
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.7356 - auc: 0.9291 - loss: 0.6267 - precision: 0.7786 - recall: 0.6800
# Epoch 9: val_accuracy improved from 0.72613 to 0.79499, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 221ms/step - accuracy: 0.7358 - auc: 0.9291 - loss: 0.6263 - precision: 0.7788 - recall: 0.6803 - val_accuracy: 0.7950 - val_auc: 0.9615 - val_loss: 0.5530 - val_precision: 0.8836 - val_recall: 0.7011
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.7862 - auc: 0.9501 - loss: 0.5309 - precision: 0.8195 - recall: 0.7397
# Epoch 10: val_accuracy did not improve from 0.79499
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - accuracy: 0.7863 - auc: 0.9501 - loss: 0.5307 - precision: 0.8195 - recall: 0.7398 - val_accuracy: 0.7934 - val_auc: 0.9625 - val_loss: 0.4788 - val_precision: 0.8309 - val_recall: 0.7230
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8064 - auc: 0.9590 - loss: 0.4778 - precision: 0.8271 - recall: 0.7740
# Epoch 11: val_accuracy improved from 0.79499 to 0.84507, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - accuracy: 0.8066 - auc: 0.9591 - loss: 0.4776 - precision: 0.8272 - recall: 0.7742 - val_accuracy: 0.8451 - val_auc: 0.9777 - val_loss: 0.4032 - val_precision: 0.8842 - val_recall: 0.8122
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8278 - auc: 0.9673 - loss: 0.4224 - precision: 0.8450 - recall: 0.7996
# Epoch 12: val_accuracy improved from 0.84507 to 0.89045, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - accuracy: 0.8279 - auc: 0.9673 - loss: 0.4221 - precision: 0.8450 - recall: 0.7998 - val_accuracy: 0.8905 - val_auc: 0.9842 - val_loss: 0.3335 - val_precision: 0.9158 - val_recall: 0.8685
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8511 - auc: 0.9741 - loss: 0.3768 - precision: 0.8639 - recall: 0.8344
# Epoch 13: val_accuracy improved from 0.89045 to 0.92801, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - accuracy: 0.8512 - auc: 0.9741 - loss: 0.3765 - precision: 0.8640 - recall: 0.8345 - val_accuracy: 0.9280 - val_auc: 0.9917 - val_loss: 0.2605 - val_precision: 0.9359 - val_recall: 0.9139
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8706 - auc: 0.9800 - loss: 0.3279 - precision: 0.8810 - recall: 0.8557
# Epoch 14: val_accuracy did not improve from 0.92801
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - accuracy: 0.8706 - auc: 0.9800 - loss: 0.3279 - precision: 0.8810 - recall: 0.8557 - val_accuracy: 0.9077 - val_auc: 0.9887 - val_loss: 0.2754 - val_precision: 0.9217 - val_recall: 0.8842
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8780 - auc: 0.9834 - loss: 0.3030 - precision: 0.8864 - recall: 0.8677
# Epoch 15: val_accuracy improved from 0.92801 to 0.93271, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - accuracy: 0.8781 - auc: 0.9834 - loss: 0.3029 - precision: 0.8865 - recall: 0.8677 - val_accuracy: 0.9327 - val_auc: 0.9958 - val_loss: 0.1974 - val_precision: 0.9364 - val_recall: 0.9218
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8988 - auc: 0.9870 - loss: 0.2618 - precision: 0.9054 - recall: 0.8907
# Epoch 16: val_accuracy did not improve from 0.93271
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - accuracy: 0.8988 - auc: 0.9870 - loss: 0.2619 - precision: 0.9053 - recall: 0.8907 - val_accuracy: 0.9249 - val_auc: 0.9942 - val_loss: 0.2221 - val_precision: 0.9385 - val_recall: 0.9077
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9073 - auc: 0.9891 - loss: 0.2424 - precision: 0.9136 - recall: 0.8981
# Epoch 17: val_accuracy improved from 0.93271 to 0.94836, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - accuracy: 0.9073 - auc: 0.9891 - loss: 0.2422 - precision: 0.9136 - recall: 0.8982 - val_accuracy: 0.9484 - val_auc: 0.9966 - val_loss: 0.1585 - val_precision: 0.9483 - val_recall: 0.9468
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9256 - auc: 0.9927 - loss: 0.1982 - precision: 0.9301 - recall: 0.9221
# Epoch 18: val_accuracy improved from 0.94836 to 0.95149, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 20s 253ms/step - accuracy: 0.9257 - auc: 0.9927 - loss: 0.1980 - precision: 0.9302 - recall: 0.9222 - val_accuracy: 0.9515 - val_auc: 0.9977 - val_loss: 0.1338 - val_precision: 0.9544 - val_recall: 0.9499
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9293 - auc: 0.9934 - loss: 0.1851 - precision: 0.9331 - recall: 0.9274
# Epoch 19: val_accuracy did not improve from 0.95149
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - accuracy: 0.9293 - auc: 0.9934 - loss: 0.1851 - precision: 0.9331 - recall: 0.9274 - val_accuracy: 0.9499 - val_auc: 0.9976 - val_loss: 0.1382 - val_precision: 0.9528 - val_recall: 0.9468
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9189 - auc: 0.9927 - loss: 0.1967 - precision: 0.9246 - recall: 0.9141
# Epoch 20: val_accuracy improved from 0.95149 to 0.95931, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - accuracy: 0.9190 - auc: 0.9927 - loss: 0.1965 - precision: 0.9247 - recall: 0.9143 - val_accuracy: 0.9593 - val_auc: 0.9974 - val_loss: 0.1249 - val_precision: 0.9622 - val_recall: 0.9562
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9403 - auc: 0.9955 - loss: 0.1539 - precision: 0.9438 - recall: 0.9372
# Epoch 21: val_accuracy did not improve from 0.95931
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - accuracy: 0.9403 - auc: 0.9955 - loss: 0.1539 - precision: 0.9438 - recall: 0.9372 - val_accuracy: 0.9531 - val_auc: 0.9974 - val_loss: 0.1307 - val_precision: 0.9560 - val_recall: 0.9515
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9371 - auc: 0.9952 - loss: 0.1573 - precision: 0.9395 - recall: 0.9344
# Epoch 22: val_accuracy improved from 0.95931 to 0.97496, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 236ms/step - accuracy: 0.9372 - auc: 0.9952 - loss: 0.1571 - precision: 0.9396 - recall: 0.9345 - val_accuracy: 0.9750 - val_auc: 0.9993 - val_loss: 0.0851 - val_precision: 0.9779 - val_recall: 0.9703
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9522 - auc: 0.9965 - loss: 0.1328 - precision: 0.9534 - recall: 0.9509
# Epoch 23: val_accuracy did not improve from 0.97496
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - accuracy: 0.9522 - auc: 0.9965 - loss: 0.1330 - precision: 0.9534 - recall: 0.9509 - val_accuracy: 0.9718 - val_auc: 0.9992 - val_loss: 0.0967 - val_precision: 0.9748 - val_recall: 0.9703
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9624 - auc: 0.9976 - loss: 0.1110 - precision: 0.9645 - recall: 0.9617
# Epoch 24: val_accuracy improved from 0.97496 to 0.98435, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - accuracy: 0.9624 - auc: 0.9976 - loss: 0.1110 - precision: 0.9645 - recall: 0.9617 - val_accuracy: 0.9844 - val_auc: 0.9994 - val_loss: 0.0768 - val_precision: 0.9859 - val_recall: 0.9828
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9624 - auc: 0.9976 - loss: 0.1075 - precision: 0.9640 - recall: 0.9599
# Epoch 25: val_accuracy did not improve from 0.98435
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - accuracy: 0.9624 - auc: 0.9976 - loss: 0.1074 - precision: 0.9641 - recall: 0.9599 - val_accuracy: 0.9828 - val_auc: 0.9997 - val_loss: 0.0565 - val_precision: 0.9828 - val_recall: 0.9828
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9637 - auc: 0.9976 - loss: 0.1007 - precision: 0.9638 - recall: 0.9625
# Epoch 26: val_accuracy did not improve from 0.98435
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 219ms/step - accuracy: 0.9636 - auc: 0.9976 - loss: 0.1007 - precision: 0.9637 - recall: 0.9624 - val_accuracy: 0.9718 - val_auc: 0.9982 - val_loss: 0.0948 - val_precision: 0.9733 - val_recall: 0.9703
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9596 - auc: 0.9967 - loss: 0.1123 - precision: 0.9612 - recall: 0.9559
# Epoch 27: val_accuracy improved from 0.98435 to 0.99531, saving model to C:\Users\Nikkhil_Bisht\Desktop\A\alzheimers-detection-main\App\model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 219ms/step - accuracy: 0.9596 - auc: 0.9967 - loss: 0.1123 - precision: 0.9612 - recall: 0.9558 - val_accuracy: 0.9953 - val_auc: 0.9999 - val_loss: 0.0580 - val_precision: 0.9953 - val_recall: 0.9906
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9682 - auc: 0.9986 - loss: 0.0850 - precision: 0.9690 - recall: 0.9669
# Epoch 28: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - accuracy: 0.9682 - auc: 0.9986 - loss: 0.0851 - precision: 0.9690 - recall: 0.9669 - val_accuracy: 0.9797 - val_auc: 0.9993 - val_loss: 0.0633 - val_precision: 0.9812 - val_recall: 0.9797
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9650 - auc: 0.9977 - loss: 0.0998 - precision: 0.9667 - recall: 0.9638
# Epoch 29: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 221ms/step - accuracy: 0.9651 - auc: 0.9977 - loss: 0.0998 - precision: 0.9667 - recall: 0.9638 - val_accuracy: 0.9890 - val_auc: 0.9997 - val_loss: 0.0483 - val_precision: 0.9890 - val_recall: 0.9859
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9635 - auc: 0.9977 - loss: 0.0997 - precision: 0.9648 - recall: 0.9622
# Epoch 30: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - accuracy: 0.9636 - auc: 0.9977 - loss: 0.0996 - precision: 0.9648 - recall: 0.9622 - val_accuracy: 0.9859 - val_auc: 0.9998 - val_loss: 0.0483 - val_precision: 0.9859 - val_recall: 0.9859
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9627 - auc: 0.9982 - loss: 0.0934 - precision: 0.9635 - recall: 0.9621
# Epoch 31: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - accuracy: 0.9627 - auc: 0.9982 - loss: 0.0934 - precision: 0.9635 - recall: 0.9621 - val_accuracy: 0.9875 - val_auc: 0.9998 - val_loss: 0.0467 - val_precision: 0.9875 - val_recall: 0.9875
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9778 - auc: 0.9990 - loss: 0.0647 - precision: 0.9792 - recall: 0.9775
# Epoch 32: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - accuracy: 0.9778 - auc: 0.9990 - loss: 0.0646 - precision: 0.9792 - recall: 0.9775 - val_accuracy: 0.9906 - val_auc: 0.9999 - val_loss: 0.0332 - val_precision: 0.9906 - val_recall: 0.9890
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9663 - auc: 0.9976 - loss: 0.0885 - precision: 0.9667 - recall: 0.9662
# Epoch 33: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 243ms/step - accuracy: 0.9664 - auc: 0.9976 - loss: 0.0884 - precision: 0.9667 - recall: 0.9663 - val_accuracy: 0.9875 - val_auc: 0.9997 - val_loss: 0.0439 - val_precision: 0.9890 - val_recall: 0.9859
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9774 - auc: 0.9993 - loss: 0.0624 - precision: 0.9780 - recall: 0.9768
# Epoch 34: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 19s 232ms/step - accuracy: 0.9773 - auc: 0.9993 - loss: 0.0625 - precision: 0.9780 - recall: 0.9768 - val_accuracy: 0.9812 - val_auc: 0.9997 - val_loss: 0.0543 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9791 - auc: 0.9992 - loss: 0.0588 - precision: 0.9803 - recall: 0.9777
# Epoch 35: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - accuracy: 0.9791 - auc: 0.9992 - loss: 0.0589 - precision: 0.9802 - recall: 0.9776 - val_accuracy: 0.9781 - val_auc: 0.9990 - val_loss: 0.0736 - val_precision: 0.9796 - val_recall: 0.9750
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9779 - auc: 0.9989 - loss: 0.0633 - precision: 0.9783 - recall: 0.9773
# Epoch 36: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - accuracy: 0.9778 - auc: 0.9989 - loss: 0.0633 - precision: 0.9783 - recall: 0.9773 - val_accuracy: 0.9859 - val_auc: 0.9996 - val_loss: 0.0550 - val_precision: 0.9890 - val_recall: 0.9812
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9749 - auc: 0.9987 - loss: 0.0673 - precision: 0.9760 - recall: 0.9735
# Epoch 37: val_accuracy did not improve from 0.99531
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 223ms/step - accuracy: 0.9749 - auc: 0.9987 - loss: 0.0674 - precision: 0.9760 - recall: 0.9735 - val_accuracy: 0.9890 - val_auc: 0.9996 - val_loss: 0.0482 - val_precision: 0.9906 - val_recall: 0.9875
# Epoch 37: early stopping

# %% [markdown]
# # Plot the result

# %%
result = model.evaluate(test_ds)
train_loss = result[0]
train_accuracy = result[1]
train_AUC = result[2]
train_pre = result[3]
train_rec = result[4]
print(f'Test Loss = {train_loss}')
print(f'Test Accuracy = {train_accuracy}')
print(f'Test AUC = {train_AUC}')
print(f'Test Precision = {train_pre}')
print(f'Test Recall = {train_rec}')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.9959 - auc: 0.9999 - loss: 0.0397 - precision: 0.9959 - recall: 0.9954
# Test Loss = 0.04290562495589256
# Test Accuracy = 0.9906542301177979
# Test AUC = 0.9998152256011963
# Test Precision = 0.9906396269798279
# Test Recall = 0.9890965819358826

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
get_pre = hist.history['precision']
get_rec = hist.history['recall']
get_auc = hist.history['auc']

val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']

# %%
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.plot(epochs, get_pre, 'm', label='Precision of Training data')
plt.plot(epochs, get_rec, 'b', label='Recall of Training data')
plt.plot(epochs, get_auc, 'y', label='AUC of Training data')

plt.title('Training data accuracy, loss, precision, recall and auc')
plt.legend(loc=0)
plt.figure()

# %%
# loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

#Accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy - ' + str(format(result[1], "0.2f")))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

#Precision
plt.plot(hist.history['precision'])
plt.plot(hist.history['val_precision'])
plt.title('model precision - ' + str(format(result[3], "0.2f")))
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

#Recall
plt.plot(hist.history['recall'])
plt.plot(hist.history['val_recall'])
plt.title('model recall - ' + str(format(result[4], "0.2f")))
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# AUC
plt.plot(hist.history['auc'])
plt.plot(hist.history['val_auc'])
plt.title('model auc - ' + str(format(result[2], "0.2f")))
plt.ylabel('auc')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
from itertools import product
y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for image_batch, label_batch in test_ds:   # use dataset.unbatch() with repeat
   # append true labels
   y_true.append(label_batch)
   # compute predictions
   preds = model.predict(image_batch)
   # append predicted labels
   y_pred.append(np.argmax(preds, axis = 1))

# convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)
correct_labels = np.argmax(correct_labels,axis=1)
confusion_mtx = confusion_matrix(correct_labels, predicted_labels)

# Define the class labels
class_names = ['Mild', 'Moderate', 'Non', 'Very']

# Plot the confusion matrix
plt.imshow(confusion_mtx, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
fmt = 'd'
thresh = confusion_mtx.max() / 2.
for i, j in product(range(confusion_mtx.shape[0]), range(confusion_mtx.shape[1])):
    plt.text(j, i, format(confusion_mtx[i, j], fmt),
             horizontalalignment="center",
             color="white" if confusion_mtx[i, j] > thresh else "black")
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
